# %%
from time import asctime
import pandas as pd
import numpy as np
import logging
import string
import nltk
from  collections import Counter
from sklearn.model_selection import train_test_split
import random

import torch 
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader , TensorDataset

# preprocessingfile = 'preprocessing.log'
datafile = 'Train.txt'
# logging.basicConfig(filename = preprocessingfile , format='%(asctime)s %(message)s',filemode='w')
# logger = logging.getLogger()
input , output = [], []
# logger.setLevel(logging.DEBUG)
with open(datafile) as file:
    for line in file.readlines():
        text = line.split(',')
        input.append(text[0][1:-1])
        output.append(text[1].strip()[1:-1])

# %%
seed = 123
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
test_input , test_output = [], []
test_datafile = '/data1/home/armangupta/Semester 3/DLNLP/Assignment_4_A/Assignment4aTestDataset.txt'

with open(test_datafile) as file:
    for line in file.readlines():
        text = line.split(',')
        test_input.append(text[0][1:-1])
        test_output.append(text[1].strip()[1:-1])

# %%
special = set()
for inp in input:
    for i in inp:
        if not i.isalnum():
            special.add(i)
special
# Out:
# {' ', '/'}

# %%
test_input
# Out:
# ['august 14 1733',
#  'monday 24 november 1625',
#  'january 24 1723',
#  '1551 18 nov',
#  'aug 10 1591',
#  '3 november 2064',
#  '1554 21 jun',
#  'december 29 1661',
#  'monday december 15 1919',
#  'may 8 1727',
#  'friday 8 february 2064',
#  '8/27/05',
#  '28/05/1572',
#  'wed 7 nov 1860',
#  'october 19 1761',
#  'march 30 1816',
#  '28 august 1795',
#  '12/21/93',
#  'march 29 1980',
#  'august 17 1706',
#  'december 11 1775',
#  'february 20 1899',
#  '9/12/35',
#  'aug 24 1893',
#  '31 july 1897',
#  'sunday april 28 1624',
#  'dec 30 1562',
#  'may 2 1580',
#  'jan 1 1665',
#  '22 september 1861',
#  'january 1 1872',
#  '1992 12 april',
#  'october 20 1885',
#  'may 20 1649',
#  '11 aug 1600',
#  'thursday september 22 1644',
#  '21 may 1572',
#  'sun 25 jun 1820',
#  'tue 18 may 2055',
#  'nov 18 2057',
#  'sunday november 17 1946',
#  '25 may 1658',
#  '1740 3 sep',
#  'nov 22 1986',
#  'mar 24 1950',
#  '1864 29 mar',
#  'saturday january 26 1658',
#  '7 march 1939',
#  'may 27 1793',
#  'tuesday december 9 1845',
#  '5 september 1806',
#  'apr 13 1648',
#  'april 8 1702',
#  '28/08/2011',
#  '12 july 1956',
#  'thursday november 24 1521',
#  '7 september 1880',
#  '11 august 1568',
#  'sat 24 oct 1925',
#  'sat 7 jul 1601',
#  'january 7 1952',
#  'april 8 2057',
#  '20 april 1825',
#  'sep 5 1674',
#  'wednesday 1875 14 07',
#  'saturday 1993 13 02',
#  '18 june 1764',
#  '6 september 1649',
#  'saturday 1704 4 10',
#  'sunday november 2 1975',
#  'december 21 1691',
#  'march 11 1887',
#  '1608 14 dec',
#  'sunday 17 march 1889',
#  '1811 14 jul',
#  '6 march 2060',
#  'october 27 1689',
#  'sunday 1723 20 06',
#  'jan 14 1655',
#  '11/11/1712',
#  '16 may 1729',
#  'december 7 1827',
#  '29/04/1553',
#  'jul 21 1566',
#  '7 september 1914',
#  'march 11 1696',
#  'october 18 1740',
#  '30 sep 1763',
#  'june 23 1554',
#  'mon 1839 8 july',
#  '15 january 1750',
#  'saturday april 24 1649',
#  'may 3 1860',
#  'sat 18 jun 1977',
#  'tuesday 1963 5 03',
#  '18 september 1588',
#  '9 september 1690',
#  'dec 24 1950',
#  'fri 30 jan 2060',
#  '1637 18 august',
#  '25 may 1579',
#  '19 may 1528',
#  'thursday 15 january 1733',
#  '11/20/54',
#  '8/16/84',
#  'friday march 18 1555',
#  'sep 22 1601',
#  'sun 13 sep 1925',
#  'dec 4 1732',
#  '17 may 1545',
#  'april 14 1888',
#  '17 july 1618',
#  'tue 1665 13 january',
#  'feb 18 1964',
#  'october 11 1699',
#  '21 june 2038',
#  'may 25 1847',
#  '5/8/30',
#  'december 6 1609',
#  'wednesday july 11 1708',
#  'jan 4 1866',
#  'july 18 1746',
#  'june 26 1777',
#  '1620 27 march',
#  'tue 1635 6 february',
#  '14 nov 1590',
#  'mar 28 1725',
#  'april 3 1697',
#  'february 7 1796',
#  'january 10 1657',
#  'may 19 1577',
#  '1873 7 feb',
#  '1999 25 mar',
#  '2033 4 july',
#  'january 3 1624',
#  'april 9 1688',
#  '30 september 1829',
#  'august 4 1691',
#  'monday december 2 1940',
#  'oct 29 1563',
#  'apr 22 1621',
#  'july 8 1603',
#  'january 2 1885',
#  'mar 15 2060',
#  'apr 2 1871',
#  '31 march 1786',
#  'october 23 1801',
#  'monday 9 january 1961',
#  'sunday april 3 1740',
#  '7 august 1628',
#  '19/07/2021',
#  'february 1 1974',
#  'thursday september 4 1569',
#  '8 august 1933',
#  'september 27 1959',
#  'september 27 1882',
#  '2015 3 january',
#  'december 19 1792',
#  'october 30 1969',
#  '1/13/17',
#  'sun 17 aug 1704',
#  'monday february 17 1896',
#  'feb 21 1528',
#  '20/10/1914',
#  '26/03/1696',
#  'sat 1888 28 july',
#  '21 may 1948',
#  '28 january 1586',
#  '23 june 1685',
#  '15 february 1791',
#  '23 july 1968',
#  '17 august 1538',
#  'mon 13 apr 1914',
#  'wednesday 11 september 1686',
#  'mar 2 1690',
#  'nov 9 1785',
#  '19/08/1578',
#  'march 3 1727',
#  '6/23/25',
#  '25/12/2068',
#  'mon 1612 1 october',
#  'sunday may 1 2016',
#  'fri 1689 18 march',
#  '24 june 2055',
#  '1638 1 nov',
#  'december 2 1731',
#  'tue 4 jan 1622',
#  'sunday july 28 1996',
#  '14 april 2027',
#  'sunday october 5 1687',
#  'oct 16 1707',
#  'jun 20 1702',
#  'jun 30 1542',
#  'monday may 2 1774',
#  '18 september 1793',
#  'thursday 22 october 1959',
#  '1756 14 december',
#  '21/07/2065',
#  'july 30 1978',
#  'wed 30 mar 1735',
#  'july 28 1940',
#  '24 january 2049',
#  'thu 22 sep 1949',
#  'wednesday october 30 1557',
#  'tue 1701 25 october',
#  'saturday 1621 15 05',
#  'jun 9 1710',
#  'wednesday august 4 1813',
#  'july 2 1571',
#  'february 25 1905',
#  '10 august 1986',
#  '1586 7 jun',
#  'july 4 2066',
#  'mon 12 may 2042',
#  'fri 1804 20 january',
#  '4 april 1881',
#  'friday january 4 1630',
#  '25 october 1846',
#  '29/04/1889',
#  '26 apr 1595',
#  'december 7 1782',
#  'monday july 17 1820',
#  'november 26 1797',
#  'monday october 11 1773',
#  'sat 12 dec 1626',
#  '2032 17 apr',
#  '2057 2 jul',
#  '09/08/1581',
#  'february 4 1716',
#  'jun 28 1787',
#  'tuesday 1554 3 08',
#  'nov 16 1850',
#  'jan 3 2047',
#  '26 august 1830',
#  '1 november 1988',
#  'jun 13 1761',
#  '6 september 1743',
#  'aug 16 1662',
#  'friday january 19 1624',
#  'november 25 1683',
#  'oct 19 1550',
#  'april 4 1678',
#  'saturday 25 august 1962',
#  '30 november 1820',
#  '1 may 1835',
#  '2/20/16',
#  '24 august 1566',
#  'january 22 1578',
#  'november 3 1720',
#  '7 april 2020',
#  'apr 30 1550',
#  '2015 13 august',
#  '13 december 1962',
#  '15 february 1698',
#  '6 january 1616',
#  'friday march 23 1753',
#  '20 november 1975',
#  'wed 1656 10 may',
#  'tue 2033 13 december',
#  'monday 1658 31 12',
#  '02/11/1821',
#  'thursday 1855 5 07',
#  'may 15 1979',
#  '08/11/2050',
#  'april 9 2057',
#  'wed 14 oct 1970',
#  'sunday january 8 1747',
#  '1954 9 jun',
#  '1 august 1696',
#  'march 30 1536',
#  '30 november 1939',
#  '25 december 1605',
#  '30/09/1920',
#  '1 december 2021',
#  'wednesday april 30 1851',
#  '1/27/70',
#  'march 25 1783',
#  '31/10/1813',
#  'jun 11 1848',
#  '16 september 1804',
#  'thursday november 2 1741',
#  'sunday may 23 1717',
#  'friday october 30 1525',
#  'mar 9 1978',
#  '6 december 1558',
#  'friday july 27 1951',
#  'feb 26 1633',
#  '24/04/1637',
#  'saturday 1998 2 01',
#  '14 september 1945',
#  '1717 29 january',
#  'feb 21 1539',
#  '30/01/1857',
#  'may 21 1975',
#  'sep 1 1745',
#  '14 mar 1960',
#  '20 july 1611',
#  '17 august 1996',
#  '3 august 2054',
#  'may 10 1612',
#  'feb 14 1559',
#  'friday 1628 14 04',
#  '18 april 1576',
#  'apr 25 1894',
#  'friday 14 june 1771',
#  'february 19 1837',
#  '23/05/1528',
#  'february 16 1926',
#  'monday june 23 2031',
#  'thursday january 10 1901',
#  '8 january 1614',
#  '23 january 1534',
#  'october 20 1691',
#  'august 13 1731',
#  'aug 22 1867',
#  'monday december 12 1549',
#  'sun 1842 20 february',
#  '27 april 1529',
#  'thu 1521 8 december',
#  'jul 21 1673',
#  '22/12/1690',
#  '5 sep 1728',
#  '3 jan 1838',
#  'august 8 1669',
#  'saturday 1814 15 01',
#  'fri 1843 20 october',
#  '17 july 1829',
#  '28 september 2026',
#  '3 may 1834',
#  '2 july 1695',
#  'may 8 1619',
#  'july 23 1561',
#  'sunday december 14 1952',
#  'apr 4 1525',
#  'sep 14 1767',
#  'mar 27 1937',
#  'february 19 1553',
#  'feb 28 1988',
#  '10 sep 1874',
#  'friday 1654 1 05',
#  'sunday february 6 1594',
#  '4 august 2022',
#  'november 21 1692',
#  'saturday 21 september 1850',
#  '12/23/43',
#  'november 7 1894',
#  'july 21 1909',
#  '9 september 1764',
#  '13 june 1641',
#  'tuesday july 6 2038',
#  'sunday 22 june 1547',
#  '1869 8 may',
#  '17/11/2012',
#  '3/19/04',
#  '25 may 1896',
#  '24/08/1790',
#  '17 august 1815',
#  'wednesday 1904 3 02',
#  '1714 5 nov',
#  '15 january 1559',
#  'march 26 2001',
#  '17 february 1592',
#  '7 april 1599',
#  'sunday july 25 1813',
#  'sep 21 1541',
#  '1829 2 june',
#  '11 july 1841',
#  '22 january 1734',
#  'tuesday 1547 25 11',
#  'aug 27 1638',
#  'wed 21 aug 1918',
#  '3/27/90',
#  'sunday april 9 1578',
#  'saturday 7 december 1641',
#  'aug 27 1813',
#  '21 june 1685',
#  '12 february 1819',
#  '19 april 1651',
#  'november 7 1537',
#  'november 24 2068',
#  'july 7 1800',
#  'aug 16 1742',
#  'january 20 1846',
#  'jun 4 1570',
#  'dec 18 1986',
#  '16 january 1533',
#  'tuesday january 13 2054',
#  '3/18/70',
#  '7 march 1809',
#  '9 november 1844',
#  '11 dec 1897',
#  '1524 17 aug',
#  'oct 12 1595',
#  'january 7 1929',
#  '09/11/1920',
#  'wednesday february 1 2045',
#  'february 3 1766',
#  '12/8/02',
#  'sep 18 1670',
#  'monday 18 january 1593',
#  '18 october 2066',
#  '5 aug 1878',
#  '4 january 1788',
#  '1740 24 february',
#  '10 apr 1997',
#  '2 july 1885',
#  '10 december 2061',
#  'feb 11 2040',
#  'july 7 1778',
#  'jul 29 1803',
#  'thursday august 29 1720',
#  '07/10/1705',
#  'thursday january 24 1771',
#  '2 feb 2063',
#  '15 feb 1620',
#  'saturday august 8 1598',
#  'sunday 4 february 1629',
#  '11 apr 1971',
#  'january 18 1841',
#  '1736 13 jul',
#  'sep 20 1791',
#  'september 19 1984',
#  'monday 1865 5 06',
#  'march 19 2011',
#  'sunday march 13 1853',
#  '12 jun 1758',
#  '8 october 1840',
#  'dec 31 1953',
#  'jun 13 1577',
#  'friday 13 march 1739',
#  'august 18 1524',
#  'july 29 1617',
#  '6 november 1547',
#  '03/08/1708',
#  '12/30/40',
#  '01/08/1908',
#  'jun 14 1556',
#  '24 may 1589',
#  '1911 14 jun',
#  'monday march 26 1551',
#  '1847 29 august',
#  'april 21 1656',
#  'april 28 1817',
#  'thursday 8 august 1895',
#  '23 march 1726',
#  '27 september 1954',
#  '1888 24 june',
#  '07/06/1550',
#  'saturday april 19 1766',
#  'monday july 15 1585',
#  'tue 1952 18 march',
#  'sep 10 1999',
#  '2 november 1597',
#  '5 aug 1835',
#  'thursday october 21 1723',
#  'december 31 1744',
#  '9 sep 1944',
#  '28 december 1836',
#  'tuesday 1633 23 08',
#  'wednesday november 21 2046',
#  '2 july 1912',
#  'sunday september 22 1540',
#  'sat 1586 21 june',
#  'december 10 1620',
#  '31 august 1679',
#  '23 jul 1871',
#  '28 february 1756',
#  '8 may 1928',
#  'mon 1862 18 august',
#  'november 9 2047',
#  'jul 13 1585',
#  'thursday 18 may 1780',
#  '7/16/70',
#  '31/03/1924',
#  '26 dec 1663',
#  'monday 1 november 1926',
#  'sat 1917 24 november',
#  '18 august 2070',
#  'january 1 1890',
#  '24 march 1763',
#  '3 august 2060',
#  'february 8 1969',
#  'saturday may 8 1734',
#  'fri 2045 8 september',
#  'october 17 1905',
#  '23 april 1969',
#  'july 16 1580',
#  'august 21 1533',
#  'thursday may 8 1614',
#  'monday september 26 1864',
#  '22 november 1904',
#  'tuesday 9 september 1941',
#  'thursday 1981 3 09',
#  'saturday 1901 25 05',
#  'june 2 1527',
#  'friday 29 september 2028',
#  '26 july 1708',
#  'feb 8 1674',
#  'october 29 1818',
#  'jan 4 1974',
#  'jan 20 1569',
#  'monday july 31 2017',
#  'thursday 1559 24 09',
#  '2040 27 november',
#  '11 august 1880',
#  '5 october 1965',
#  'thursday june 28 1759',
#  '3 sep 2068',
#  '2030 6 november',
#  '14 february 1613',
#  'sunday august 5 1556',
#  'september 19 1582',
#  '15 november 2059',
#  'apr 20 1761',
#  '1726 8 october',
#  '26 november 1605',
#  'tue 1593 2 february',
#  'monday 1959 30 03',
#  'tuesday december 23 1834',
#  'monday 1747 1 05',
#  'july 2 1749',
#  'tuesday march 28 1747',
#  'june 21 2042',
#  'tue 2 jun 1936',
#  '2/22/17',
#  'august 22 1641',
#  'november 9 1758',
#  'august 2 1877',
#  '8 november 1681',
#  '1625 15 mar',
#  'sunday december 20 1609',
#  '24 october 1873',
#  'march 14 1895',
#  '1851 23 apr',
#  'tue 20 mar 1534',
#  'dec 11 1886',
#  '1 august 1673',
#  'thursday april 10 1845',
#  'june 28 1755',
#  '27 dec 1803',
#  '13 jul 1838',
#  'january 6 1918',
#  '01/04/1710',
#  '14/10/1767',
#  '25 may 2007',
#  '1 oct 2003',
#  '26 february 1850',
#  'may 23 1728',
#  'friday 15 august 1608',
#  '30 september 1848',
#  'april 22 2051',
#  'aug 14 2055',
#  'tuesday march 15 1560',
#  'saturday 19 february 1555',
#  '1998 13 jan',
#  '27 november 1961',
#  'mar 12 1563',
#  '6/8/64',
#  'april 5 1787',
#  '5 november 1978',
#  'wednesday january 18 1978',
#  '14 january 1841',
#  '30 mar 1656',
#  '23 december 2017',
#  '15 july 1876',
#  '11 apr 1997',
#  '31 may 1609',
#  'february 3 1652',
#  'dec 17 1791',
#  '08/01/1915',
#  'february 28 1825',
#  'sunday 13 april 1524',
#  'august 27 1530',
#  '7 march 1904',
#  '9 march 2001',
#  'tuesday 31 may 2050',
#  'tuesday february 14 1708',
#  '7 april 1945',
#  'january 30 1992',
#  'jul 14 1933',
#  'saturday 1624 2 11',
#  'november 27 1895',
#  '4 november 1824',
#  '22/11/1691',
#  '1658 2 february',
#  'monday 2 october 1550',
#  'monday 1616 17 10',
#  'august 21 1670',
#  'jan 31 1791',
#  '3 march 2029',
#  'wednesday september 2 1835',
#  '31 jan 1985',
#  'aug 24 1941',
#  '14/09/1797',
#  'nov 9 1699',
#  'apr 24 1841',
#  '26 august 2066',
#  'december 11 1642',
#  '23 october 1757',
#  'sunday july 19 1829',
#  '1889 3 december',
#  'jul 16 1962',
#  'jan 3 1914',
#  'tuesday 29 january 1585',
#  'september 28 1899',
#  'december 28 1670',
#  '1871 12 september',
#  '1 february 1736',
#  'wednesday 30 august 1684',
#  '7 november 2031',
#  '04/05/1967',
#  'september 7 2059',
#  'july 28 1847',
#  'november 19 1550',
#  '02/08/1734',
#  '9/22/58',
#  '1733 17 mar',
#  'sep 16 2071',
#  '1607 17 april',
#  '5 august 1570',
#  '27/03/1973',
#  '5 october 1774',
#  '1773 11 july',
#  'thu 25 mar 1880',
#  'tuesday 1553 3 11',
#  'may 14 1745',
#  'saturday 1639 29 10',
#  'friday june 20 1884',
#  'thu 1621 13 may',
#  'tuesday november 28 1916',
#  'november 10 1826',
#  '29/08/1610',
#  '19 november 1948',
#  'july 9 1775',
#  'sunday 1752 1 10',
#  'jun 14 1847',
#  'saturday june 18 1932',
#  'sunday 10 november 1918',
#  'aug 27 1626',
#  '23 december 2050',
#  '13 november 1786',
#  'june 28 1881',
#  '4 january 2059',
#  'april 17 1559',
#  'mar 27 1868',
#  'tuesday 1593 12 10',
#  'monday november 4 1799',
#  'january 19 1987',
#  '1984 10 jul',
#  'sep 8 1751',
#  '1992 27 july',
#  'september 12 1741',
#  '7 november 1873',
#  'nov 7 1943',
#  'wednesday february 13 1585',
#  'thursday 1781 4 10',
#  'january 22 1533',
#  '15 january 1743',
#  '1793 11 dec',
#  'tue 15 feb 1820',
#  'april 8 1584',
#  '21/06/1579',
#  '1609 12 feb',
#  '2 december 1757',
#  '20/09/1532',
#  'mar 22 1801',
#  'aug 4 1730',
#  'thursday march 27 1710',
#  '15 aug 1962',
#  '14 february 2020',
#  '5/25/56',
#  'may 30 1666',
#  'saturday 4 april 1936',
#  'december 6 1628',
#  'mon 11 aug 1692',
#  'june 17 1872',
#  '1955 28 february',
#  'oct 31 1752',
#  'mon 1901 14 january',
#  'mar 6 1593',
#  'january 11 1654',
#  '17/10/1879',
#  '4 july 1565',
#  'jun 4 1700',
#  'october 28 1682',
#  '1566 15 april',
#  'january 30 1651',
#  '24 february 1693',
#  'june 7 2071',
#  'sunday september 17 1837',
#  'february 1 2047',
#  'may 21 1979',
#  'july 22 1557',
#  '19 november 1808',
#  'thursday 1567 20 04',
#  'sunday march 21 1565',
#  'sunday january 13 1529',
#  'september 9 1546',
#  '6 sep 1705',
#  'friday 2049 15 01',
#  'october 10 1654',
#  'may 11 1724',
#  '21 jul 1990',
#  '26 october 1943',
#  'friday 10 september 1723',
#  '12 june 1874',
#  'oct 13 1838',
#  '26 april 1981',
#  'may 31 1564',
#  'december 28 1932',
#  'september 21 1925',
#  '20 may 2023',
#  'sep 21 1785',
#  '23/01/1608',
#  '30 december 1570',
#  'mar 31 1644',
#  'saturday 1827 17 02',
#  'wednesday january 25 1882',
#  'dec 28 1758',
#  '16 november 2053',
#  'saturday 2050 11 06',
#  'saturday may 3 1997',
#  '1924 1 jun',
#  '16 november 1921',
#  'dec 22 1962',
#  'march 26 1736',
#  '1912 21 june',
#  '01/07/1639',
#  '1 october 1864',
#  '1777 27 december',
#  '23 july 1974',
#  '1 february 1668',
#  '8 january 1705',
#  '17 jul 1667',
#  'tuesday 25 february 1800',
#  '1726 15 nov',
#  '1561 13 march',
#  'mar 28 2063',
#  '18/02/1620',
#  'jun 6 1635',
#  'saturday september 12 1885',
#  'wed 23 jul 1941',
#  '1839 8 december',
#  '14 may 1802',
#  '4/19/36',
#  'february 21 1830',
#  'thursday march 22 1770',
#  '10/02/1671',
#  'may 20 1831',
#  'nov 11 1907',
#  'june 26 1904',
#  '6 november 1620',
#  '10/3/91',
#  'sun 1849 22 april',
#  'wed 17 jan 1646',
#  'sunday 21 november 1756',
#  'tue 1707 15 march',
#  'monday 1986 30 12',
#  'september 14 1575',
#  '8/21/65',
#  'october 18 2023',
#  '1628 28 november',
#  'august 23 1591',
#  '5 february 1864',
#  'fri 25 jul 1930',
#  '6 november 2029',
#  'friday 16 february 1810',
#  'may 29 1730',
#  '6 december 1739',
#  '1681 6 august',
#  '1726 27 aug',
#  '1552 21 jan',
#  'sat 1890 14 june',
#  'oct 4 1679',
#  'tuesday 1647 22 10',
#  'aug 12 1951',
#  'nov 14 1590',
#  'jan 29 1632',
#  'nov 25 1570',
#  '20 november 1619',
#  'saturday june 12 1886',
#  'july 18 2060',
#  'wednesday july 12 1944',
#  'apr 11 1592',
#  '6 december 1749',
#  '22 august 1893',
#  'sunday march 29 1536',
#  '7 may 2063',
#  '6 january 2013',
#  'sunday 17 february 1760',
#  'mon 25 sep 2045',
#  '25 march 1876',
#  'august 6 1998',
#  'sunday august 18 1715',
#  'oct 4 1978',
#  'jan 27 2011',
#  'apr 8 1803',
#  'february 14 1888',
#  '1761 20 jun',
#  'fri 22 nov 1535',
#  'september 5 1967',
#  '1 august 2033',
#  'wed 19 dec 1629',
#  'jun 14 1983',
#  '1717 4 jan',
#  '5/3/33',
#  '22 june 1980',
#  'mon 16 aug 2066',
#  'january 28 1854',
#  '1989 9 nov',
#  'monday march 12 2018',
#  'saturday 1930 13 09',
#  '8/21/04',
#  'sun 1642 21 september',
#  '7 jun 1781',
#  'oct 31 1558',
#  'jan 10 1599',
#  'monday october 16 1843',
#  'jun 22 1902',
#  '5/8/65',
#  'friday 6 october 1544',
#  '1524 11 august',
#  '18 september 1687',
#  'may 12 1897',
#  'aug 22 1908',
#  '1892 4 june',
#  'october 21 1644',
#  '5 october 1591',
#  'feb 8 1677',
#  '1522 29 november',
#  'march 12 1865',
#  '2/16/84',
#  'february 18 1547',
#  'sunday 27 september 1722',
#  'january 29 1646',
#  'march 9 1779',
#  'wed 31 mar 1982',
#  'feb 28 1918',
#  '1/2/27',
#  'wednesday 1728 19 05',
#  'friday november 18 1707',
#  '28 september 1868',
#  'nov 5 1803',
#  'july 17 1526',
#  '24 september 1567',
#  'july 24 1774',
#  'tuesday january 15 1907',
#  'february 13 1615',
#  'september 7 1978',
#  'august 13 2001',
#  'apr 1 2015',
#  '19 april 1757',
#  'july 31 1565',
#  '2/2/92',
#  'january 14 1827',
#  '1960 9 apr',
#  'july 10 1803',
#  'feb 23 1650',
#  'mar 4 1901',
#  '1757 21 jan',
#  '4/20/82',
#  '4 october 1569',
#  '21 january 1855',
#  '01/10/2044',
#  'june 5 1696',
#  '03/01/2067',
#  '28 november 1707',
#  'june 9 1872',
#  'friday 1974 8 03',
#  '25 february 1909',
#  'december 22 1580',
#  'apr 12 1889',
#  'friday may 19 1871',
#  '28 september 1661',
#  '13 dec 1683',
#  'fri 1690 10 november',
#  'saturday april 4 1699',
#  'thu 23 oct 2070',
#  'jan 7 1869',
#  'dec 20 1679',
#  'thursday december 29 1689',
#  'april 22 1842',
#  'thursday 18 february 1993',
#  'aug 15 1581',
#  'thursday october 13 1842',
#  'sunday 24 july 1735',
#  'may 4 1828',
#  '1608 14 sep',
#  '26 june 2058',
#  '1552 27 september',
#  '9 february 1625',
#  'wednesday november 24 1660',
#  'november 27 1597',
#  '17 april 1624',
#  '15 nov 2011',
#  '1556 8 september',
#  '19 april 1708',
#  'saturday october 3 1570',
#  '1743 17 oct',
#  'september 6 1601',
#  'mon 23 jan 1797',
#  '5 august 1598',
#  'december 7 1874',
#  'january 5 1994',
#  '23 july 1723',
#  'mar 7 1620',
#  'november 20 1820',
#  'jul 10 1771',
#  'july 17 1548',
#  '29 june 2003',
#  'december 25 1795',
#  'october 14 2063',
#  'august 25 1587',
#  '30 july 1653',
#  'june 1 1886',
#  'october 22 1805',
#  'oct 24 1776',
#  'december 26 1571',
#  'friday december 10 1610',
#  '9 may 2000',
#  'saturday november 29 1823',
#  '29/11/1869',
#  'wed 1957 6 february',
#  'sat 1638 9 october',
#  '5 september 1702',
#  'sep 3 1999',
#  'sunday 1538 8 05',
#  '14 sep 1786',
#  '1970 10 january',
#  'apr 13 1792',
#  'january 24 1743',
#  'july 30 1578',
#  'friday 13 april 1573',
#  '2054 11 mar',
#  '1976 3 april',
#  '29 april 1686',
#  'jul 2 1927',
#  'sunday july 29 1534',
#  '9/2/41',
#  '8 january 1948',
#  'october 1 2019',
#  'sunday 1745 9 05',
#  'may 23 1992',
#  'may 31 1760',
#  'tue 2011 22 november',
#  'tuesday 2013 20 08',
#  'thursday may 24 2035',
#  '29/10/1680',
#  '1805 4 jun',
#  'august 7 1717',
#  '2 september 2022',
#  'april 18 1972',
#  'november 6 2034',
#  '13 january 1578',
#  '20 dec 2058',
#  'jan 31 1993',
#  'friday 2026 24 07',
#  'monday 25 september 1797',
#  '9 feb 1556',
#  '25 april 1916',
#  '9 oct 2002',
#  'march 15 1694',
#  'december 11 2024',
#  'dec 21 1787',
#  'wednesday 2017 26 04',
#  'may 15 1917',
#  '2046 2 february',
#  '1733 3 may',
#  'december 10 1754',
#  '23 july 1841',
#  '30 may 1587',
#  'september 14 1523',
#  '10/03/1735',
#  'jul 12 1729',
#  'july 31 2011',
#  '1661 18 july',
#  'saturday 1928 11 02',
#  'january 28 1832',
#  '13 aug 1932',
#  'november 9 1599',
#  '1641 9 jul',
#  'oct 14 2045',
#  'apr 13 1893',
#  'monday july 4 1538',
#  'nov 7 1811',
#  'saturday 28 march 1615',
#  'friday april 19 1912',
#  'july 31 2062',
#  'tuesday 1654 10 02',
#  '6/18/06',
#  'friday 3 december 1971',
#  '29 may 1815',
#  'thursday 19 july 1731',
#  'saturday june 5 1886',
#  'sunday january 8 1713',
#  'april 30 1689',
#  'july 4 2026',
#  'monday january 23 1939',
#  'sunday 2042 29 06',
#  'wed 26 mar 1941',
#  ...]

# %%
class Preprocessing:
    def __init__(self):
        pass
    def lowerCase(self ,text):
        return text.lower()
    def splitText(self ,text):
        return text.replace('/',' ').replace('-', ' ').split()
    def correctNumber(self,text):
        ''' text is the array of strings.'''
        num = [str(i) for i in range(1,10)]

        text = ['0'+t if t in num else t for t in text]
        return text

    def preprocess(self,text):
        text= self.lowerCase(text) 
        text= self.splitText(text) 
        text= self.correctNumber(text) 
        return text

# %%
pre = Preprocessing()
# input = [pre.preprocess(inp) for inp in input]
# output = [pre.preprocess(out) for out in output]
inp_words ,out_words = [] ,[]
for inp in input:
    inp_words.extend(inp)

for out in output:
    for o in out:
        out_words.extend(o)

# %%
counter = Counter(inp_words)
inp_word2int = dict(zip(counter.keys() , np.arange(1, 1+len(counter))))
inp_word2int['<PAD>'] = 0
inp_word2int
# Out:
# {'m': 1,
#  'a': 2,
#  'y': 3,
#  ' ': 4,
#  '2': 5,
#  '0': 6,
#  '3': 7,
#  '4': 8,
#  '9': 9,
#  '1': 10,
#  '6': 11,
#  '5': 12,
#  '/': 13,
#  'r': 14,
#  '7': 15,
#  'j': 16,
#  'u': 17,
#  'n': 18,
#  'f': 19,
#  'i': 20,
#  'd': 21,
#  'w': 22,
#  'e': 23,
#  's': 24,
#  'p': 25,
#  't': 26,
#  'b': 27,
#  '8': 28,
#  'o': 29,
#  'c': 30,
#  'l': 31,
#  'v': 32,
#  'g': 33,
#  'h': 34,
#  '<PAD>': 0}

# %%
unique_out_words = np.unique(out_words)
out_word2int = dict(zip(unique_out_words ,np.arange(3,3+len(unique_out_words))))
out_word2int['<E>'] = 2
out_word2int['<S>'] = 1
out_word2int['<PAD>'] = 0
out_word2int
# Out:
# {'-': 3,
#  '0': 4,
#  '1': 5,
#  '2': 6,
#  '3': 7,
#  '4': 8,
#  '5': 9,
#  '6': 10,
#  '7': 11,
#  '8': 12,
#  '9': 13,
#  '<E>': 2,
#  '<S>': 1,
#  '<PAD>': 0}

# %%
## input and output encoder
input = [[inp_word2int[w] for w in inp] for inp in input]
output =[[out_word2int[w] for w in out] for out in output]
test_input = [[inp_word2int[w] for w in inp] for inp in test_input]
test_output =[[out_word2int[w] for w in out] for out in test_output]

# %%
test_input[2]
# Out:
# [16, 2, 18, 17, 2, 14, 3, 4, 5, 8, 4, 10, 15, 5, 7]

# %%
np.array(output)
# Out:
# array([[ 6,  4,  7, ...,  3,  6,  4],
#        [ 5, 10,  7, ...,  3,  4, 13],
#        [ 6,  4,  5, ...,  3,  5,  9],
#        ...,
#        [ 5, 12,  9, ...,  3,  5, 12],
#        [ 6,  4, 11, ...,  3,  5,  5],
#        [ 5, 11,  5, ...,  3,  6, 11]])

# %%
output_for_labels = np.array([np.append(out,[out_word2int['<E>']]) for out in output])
test_output_for_labels = np.array([np.append(out,[out_word2int['<E>']]) for out in test_output])

# %%
output = [np.append([out_word2int['<S>']] ,out) for out in output]
test_output = [np.append([out_word2int['<S>']] ,out) for out in test_output]

# %%
test_output = np.array(test_output)

# %%
input[:5] , output[:5] , output_for_labels[:5] , test_output_for_labels[:5]
# Out:
# ([[1, 2, 3, 4, 5, 6, 4, 5, 6, 7, 8],
#   [9, 4, 1, 2, 3, 4, 10, 11, 7, 6],
#   [10, 12, 13, 6, 7, 13, 5, 6, 10, 8],
#   [1, 2, 14, 4, 10, 11, 4, 10, 11, 15, 12],
#   [16, 17, 18, 4, 10, 11, 4, 10, 11, 8, 6]],
#  [array([1, 6, 4, 7, 8, 3, 4, 9, 3, 6, 4]),
#   array([ 1,  5, 10,  7,  4,  3,  4,  9,  3,  4, 13]),
#   array([1, 6, 4, 5, 8, 3, 4, 7, 3, 5, 9]),
#   array([ 1,  5, 10, 11,  9,  3,  4,  7,  3,  5, 10]),
#   array([ 1,  5, 10,  8,  4,  3,  4, 10,  3,  5, 10])],
#  array([[ 6,  4,  7,  8,  3,  4,  9,  3,  6,  4,  2],
#         [ 5, 10,  7,  4,  3,  4,  9,  3,  4, 13,  2],
#         [ 6,  4,  5,  8,  3,  4,  7,  3,  5,  9,  2],
#         [ 5, 10, 11,  9,  3,  4,  7,  3,  5, 10,  2],
#         [ 5, 10,  8,  4,  3,  4, 10,  3,  5, 10,  2]]),
#  array([[ 5, 11,  7,  7,  3,  4, 12,  3,  5,  8,  2],
#         [ 5, 10,  6,  9,  3,  5,  5,  3,  6,  8,  2],
#         [ 5, 11,  6,  7,  3,  4,  5,  3,  6,  8,  2],
#         [ 5,  9,  9,  5,  3,  5,  5,  3,  5, 12,  2],
#         [ 5,  9, 13,  5,  3,  4, 12,  3,  5,  4,  2]]))

# %%
len_input , len_output = np.array([len(inp) for inp in input]) , np.array([len(out)for out in output])
test_len_input = np.array([len(inp) for inp in test_input])

# %%
def padding(inputs , seq_len , pad_id):
    pad_inputs = np.full(shape = (len(inputs),seq_len) , fill_value= pad_id)
    for i,x in enumerate(inputs):
        pad_inputs[i ,:len(x)] = x 
    return pad_inputs

input = padding(input, max(len_input), inp_word2int['<PAD>'])
output = padding(output,max(len_output), out_word2int['<PAD>'])
test_input = padding(test_input,max(test_len_input),inp_word2int['<PAD>'])
print(f'Input Shape : {input.shape} , Output Shape : {output.shape} , Test Inp : {test_input.shape}')
# Out:
# Input Shape : (40000, 27) , Output Shape : (40000, 11) , Test Inp : (10000, 27)

# %%
train_input , val_input , train_output, val_output , train_input_len , val_input_len , train_output_labels , val_output_labels = train_test_split(input , output ,len_input , output_for_labels, test_size = 0.1)
print(f'Train Input Shape : {train_input.shape} , Train Output Shape : {train_output.shape} , Train Input Len Shape : {train_input_len.shape} , Train Output Len Shape :{train_output_labels.shape}')
print(f'Val Input Shape : {val_input.shape} , Val Output Shape : {val_output.shape},Val Input Len Shape : {val_input_len.shape} , Val Output Len Shape :{val_output_labels.shape}')
# Out:
# Train Input Shape : (36000, 27) , Train Output Shape : (36000, 11) , Train Input Len Shape : (36000,) , Train Output Len Shape :(36000, 11)
# Val Input Shape : (4000, 27) , Val Output Shape : (4000, 11),Val Input Len Shape : (4000,) , Val Output Len Shape :(4000, 11)

# %%
train = TensorDataset(torch.from_numpy(train_input) , torch.from_numpy(train_output) ,torch.from_numpy(train_input_len) , torch.from_numpy(train_output_labels))
validation = TensorDataset(torch.from_numpy(val_input) , torch.from_numpy(val_output) , torch.from_numpy(val_input_len) , torch.from_numpy(val_output_labels))
test = TensorDataset(torch.from_numpy(test_input) , torch.from_numpy(test_output) , torch.from_numpy(test_len_input) , torch.from_numpy(test_output_for_labels))

BATCH_SIZE = 16
trainloader = DataLoader(train , shuffle = True, batch_size = BATCH_SIZE)
valloader = DataLoader(validation, shuffle= False, batch_size = BATCH_SIZE)
testloader = DataLoader(test, shuffle= False, batch_size = BATCH_SIZE)

# %%
class Encoder(nn.Module):
    def __init__(self , vocab_size , emb_size, hidden_size , num_layers ,pad_id):
        super(Encoder, self).__init__()
        self.vocab_size = vocab_size
        self.emb_size = emb_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.embedding = nn.Embedding(self.vocab_size , self.emb_size , padding_idx= pad_id )
        self.GRU = nn.GRU(input_size = self.emb_size , hidden_size = self.hidden_size , num_layers = self.num_layers , bidirectional = True , batch_first = True)

    def forward(self, x):
        # h0 = self.initialize_weights(x.shape[0])
        embs = self.embedding(x)
        output , hn = self.GRU(embs)
        return output , hn
    
    def initialize_weights(self, batch_size):
        h0 = torch.rand(size = (self.num_layers * 2 ,batch_size, self.hidden_size))
        return h0

# %%
encoder = Encoder(len(inp_word2int) , emb_size= 30 , hidden_size= 30, num_layers=1 , pad_id= inp_word2int['<PAD>'] )
print(encoder)
# Out:
# Encoder(
#   (embedding): Embedding(35, 30, padding_idx=0)
#   (GRU): GRU(30, 30, batch_first=True, bidirectional=True)
# )

# %%
def masked_softmax(X ,valid_len):
    if valid_len == None:
      return nn.Softmax(dim = -1)(X)
    maxlen = X.shape[-1]
    if valid_len.dim() == 1:
        valid_len = valid_len.unsqueeze(1)
    # print(valid_len.shape , valid_len.dim())
    mask = torch.arange(maxlen)[None, :] < valid_len[:,:,None]
    # print(mask.shape, X.shape )
    X[~mask] = float('-inf')
    return nn.Softmax(dim = -1)(X)



class MLPAttention(nn.Module):
    def __init__(self, units, k_dim ,q_dim ,dropout):
        super(MLPAttention , self).__init__()
        self.W_k = nn.Linear(k_dim , units ,bias= False)
        self.W_q = nn.Linear(q_dim , units ,bias= False)
        self.v = nn.Linear(units , 1,bias = False)
        self.dropout = nn.Dropout(dropout)

    def forward(self,query ,key ,value,valid_len):
        query, key = self.W_q(query) , self.W_k(key)
        # print('Query ',query , key , value)
        features = query.unsqueeze(dim=2) + key.unsqueeze(dim=1)
        features = torch.tanh(features)
        scores = self.v(features).squeeze(dim=-1)
        attention_weights = self.dropout(masked_softmax(scores, valid_len))

        return torch.bmm(attention_weights , value)

# %%
attn = MLPAttention(8,2,2,0.1)
value = np.arange(40).reshape(1,10,4).repeat(2 ,axis =0)
attn(torch.ones((2,1,2)) , torch.ones((2,10,2)) , torch.from_numpy(value).float(),torch.from_numpy(np.array([2,6])))
# Out:
# tensor([[[2.2222, 3.3333, 4.4444, 5.5556]],
#
#         [[6.6667, 7.4074, 8.1481, 8.8889]]], grad_fn=<BmmBackward0>)

# %%
class Decoder(nn.Module):
    def __init__(self, vocab_size , emb_size, hidden_size , num_layers ,pad_id, enc_o_last_dim ,dropout):
        super(Decoder,self).__init__()
        self.vocab_size = vocab_size
        self.emb_size = emb_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.embedding = nn.Embedding(self.vocab_size , self.emb_size , padding_idx= pad_id)
        self.GRU = nn.GRU(input_size = self.emb_size + 2 * self.hidden_size , hidden_size = self.hidden_size, \
            num_layers = self.num_layers , batch_first = True)
        self.attn_layer = MLPAttention(units = hidden_size, k_dim = enc_o_last_dim, q_dim = self.hidden_size ,dropout = dropout)
        self.linear_softmax = nn.Sequential(
            nn.Linear(self.hidden_size , self.vocab_size),
            nn.Softmax(dim= -1)
        )
    def forward(self, X, state, train = True):
        enc_outputs , hidden_state, enc_valid_len = state
        # print("OUT:", state)
        X = self.embedding(X)
        outputs = []
        X = torch.swapaxes(X,0,1)
        teacher_forcing_ratio = 0.5
        for i in range(len(X)):
            if i == 0:
                x = X[i].unsqueeze(dim = 1)
            else:
                if train:
                    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False
                    if use_teacher_forcing:
                        x = X[i].unsqueeze(dim = 1)
                    else:
                        x = out.detach()
                else:
                    x = out.detach()
                    
            query = hidden_state[0].unsqueeze(dim = 1)
            context = self.attn_layer(query= query , key = enc_outputs, value = enc_outputs ,valid_len = enc_valid_len )
            x = torch.concat((context , x),dim=-1)
            out,hidden_state = self.GRU(x,hidden_state[0].unsqueeze(dim = 0))
            # print(out.shape)
            outputs.append(out)
        
        # print('outputs:' ,outputs)
        outputs = self.linear_softmax(torch.concat(outputs , dim=1))
        return outputs , hidden_state

# %%
encoder = Encoder(len(inp_word2int) , emb_size= 300 , hidden_size= 300, num_layers=1 , pad_id= inp_word2int['<PAD>'] )
print(encoder)
decoder = Decoder(len(out_word2int) , 300 , 300, 1, out_word2int['<PAD>'], 600, 0.1)
# Out:
# Encoder(
#   (embedding): Embedding(35, 300, padding_idx=0)
#   (GRU): GRU(300, 300, batch_first=True, bidirectional=True)
# )

# %%
from itertools import chain
from tqdm import tqdm
lr = 0.001
# enc_optimizer = torch.optim.AdamW(encoder.parameters() ,lr = 0.001)
# dec_optimizer = torch.optim.AdamW(decoder.parameters() ,lr = 0.001)
optimizer = torch.optim.AdamW(chain(encoder.parameters(),decoder.parameters()) ,lr = lr)
criteria = nn.CrossEntropyLoss()

# %%
def exactmatch(decoder_output ,actual_output):
    sum = torch.sum(decoder_output == actual_output , axis = 1)
    # print(sum)
    return torch.sum(sum == 11).item() 

def train(encoder , decoder, trainloader , valloader ,testloader, optimizer , criteria ,epochs ,device):

    for epoch in tqdm(range(epochs)):
        m_loss =[]
        m_acc = []
        encoder.train()
        decoder.train()
        total = 0
        correct = 0
        total_example = 0
        exact_match = 0
        for I, O, I_len , O_labels in tqdm(trainloader):
            I, O, I_len , O_labels = I.to(device), O.to(device), I_len , O_labels.to(device)
            loss = 0
            optimizer.zero_grad()
            # dec_optimizer.zero_grad()
            enc_o , enc_h = encoder(I)
            state = enc_o, enc_h , I_len
            decoder_o , decoder_h = decoder(O , state)
            onehotlabels = F.one_hot(O_labels , len(out_word2int) ).float()
            # print(decoder_o ,onehotlabels)
            loss = criteria(decoder_o,onehotlabels)
            loss.backward()
            # torch.nn.utils.clip_grad_norm_(encoder.parameters(), 5)
            # torch.nn.utils.clip_grad_norm_(decoder.parameters(), 5)
            optimizer.step()
            # dec_optimizer.step()
            m_loss.append(loss.item())
            accuracy = torch.mean(torch.sum(torch.argmax(decoder_o ,dim = -1) ==  O_labels ,dim = 1).float())
            correct += torch.sum(torch.argmax(decoder_o ,dim = -1) ==  O_labels)
            total += torch.sum(torch.argmax(onehotlabels ,dim = -1) ==  O_labels)
            exact_match += exactmatch(torch.argmax(decoder_o ,dim = -1) , O_labels)
            total_example+=len(O_labels)
            

        encoder.eval()
        decoder.eval()
        v_loss = []
        val_correct , val_total = 0,0
        val_total_example = 0
        val_exact_match = 0
        with torch.no_grad():
            for I, O, I_len , O_labels in tqdm(valloader):
                I, O, I_len , O_labels = I.to(device), O.to(device), I_len , O_labels.to(device)
                loss = 0
                enc_o , enc_h = encoder(I)
                state = enc_o, enc_h , I_len
                decoder_o , decoder_h = decoder(O , state ,False)
                onehotlabels = F.one_hot(O_labels , len(out_word2int) ).float()
                # print(decoder_o ,onehotlabels)
                loss = criteria(decoder_o,onehotlabels)
                v_loss.append(loss.item())
                val_correct += torch.sum(torch.argmax(decoder_o ,dim = -1) ==  O_labels)
                val_total += torch.sum(torch.argmax(onehotlabels ,dim = -1) ==  O_labels)
                val_exact_match += exactmatch(torch.argmax(decoder_o ,dim = -1) , O_labels)
                val_total_example+=len(O_labels)
        
        test_loss = []
        test_correct , test_total = 0,0
        test_total_example = 0
        test_exact_match = 0
        with torch.no_grad():
            for I, O, I_len , O_labels in tqdm(testloader):
                I, O, I_len , O_labels = I.to(device), O.to(device), I_len , O_labels.to(device)
                loss = 0
                enc_o , enc_h = encoder(I)
                state = enc_o, enc_h , I_len
                decoder_o , decoder_h = decoder(O , state ,False)
                onehotlabels = F.one_hot(O_labels , len(out_word2int) ).float()
                # print(decoder_o ,onehotlabels)
                loss = criteria(decoder_o, onehotlabels)
                test_loss.append(loss.item())
                test_correct += torch.sum(torch.argmax(decoder_o ,dim = -1) ==  O_labels)
                test_total += torch.sum(torch.argmax(onehotlabels ,dim = -1) ==  O_labels)
                test_exact_match += exactmatch(torch.argmax(decoder_o ,dim = -1) , O_labels)
                test_total_example+=len(O_labels)
        print(f'epoch {epoch} || train loss : {np.mean(m_loss)} ||train acc : {correct/total} || ExactMatch train Acc :{exact_match/total_example} || val loss : {np.mean(v_loss)} || val acc : {val_correct/val_total} ||  ExactMatch val Acc :{val_exact_match/val_total_example} ||test loss : {np.mean(test_loss)} || test acc : {test_correct/test_total} ||  ExactMatch test Acc :{test_exact_match/test_total_example}     ')

# %%
device = 'cuda:1' if torch.cuda.is_available() else 'cpu'
# device = 'cpu'
encoder = encoder.to(device)
decoder = decoder.to(device)

train(encoder, decoder , trainloader , valloader,testloader, optimizer ,criteria , 100 , device)
# Out:
# 100%|██████████| 2250/2250 [01:38<00:00, 22.74it/s]
# 100%|██████████| 250/250 [00:04<00:00, 58.39it/s]
# 100%|██████████| 625/625 [00:10<00:00, 61.25it/s]
#   1%|          | 1/100 [01:53<3:07:12, 113.46s/it]
# epoch 0 || train loss : 1.3511079547670153 ||train acc : 0.9073636531829834 || ExactMatch train Acc :0.5185277777777778 || val loss : 1.303944194316864 || val acc : 0.9772727489471436 ||  ExactMatch val Acc :0.76975 ||test loss : 1.302432506942749 || test acc : 0.9777363538742065 ||  ExactMatch test Acc :0.7738
# 100%|██████████| 2250/2250 [01:39<00:00, 22.63it/s]
# 100%|██████████| 250/250 [00:03<00:00, 66.31it/s]
# 100%|██████████| 625/625 [00:09<00:00, 65.65it/s]
#   2%|▏         | 2/100 [03:46<3:04:37, 113.04s/it]
# epoch 1 || train loss : 1.296619619846344 ||train acc : 0.9860782623291016 || ExactMatch train Acc :0.8625833333333334 || val loss : 1.2918150806427002 || val acc : 0.9943863749504089 ||  ExactMatch val Acc :0.95 ||test loss : 1.2906443796157836 || test acc : 0.9942272901535034 ||  ExactMatch test Acc :0.9469
# 100%|██████████| 2250/2250 [01:41<00:00, 22.11it/s]
# 100%|██████████| 250/250 [00:04<00:00, 61.55it/s]
# 100%|██████████| 625/625 [00:10<00:00, 57.86it/s]
#   3%|▎         | 3/100 [05:42<3:05:23, 114.68s/it]
# epoch 2 || train loss : 1.2908911911116705 ||train acc : 0.9940782785415649 || ExactMatch train Acc :0.9433888888888889 || val loss : 1.28994065618515 || val acc : 0.9963863492012024 ||  ExactMatch val Acc :0.968 ||test loss : 1.2886151863098145 || test acc : 0.996536374092102 ||  ExactMatch test Acc :0.9681
# 100%|██████████| 2250/2250 [01:40<00:00, 22.43it/s]
# 100%|██████████| 250/250 [00:03<00:00, 64.94it/s]
# 100%|██████████| 625/625 [00:09<00:00, 64.76it/s]
#   4%|▍         | 4/100 [07:36<3:02:57, 114.35s/it]
# epoch 3 || train loss : 1.2902335262828404 ||train acc : 0.9948409199714661 || ExactMatch train Acc :0.9493611111111111 || val loss : 1.2898715505599976 || val acc : 0.9965454339981079 ||  ExactMatch val Acc :0.9685 ||test loss : 1.2885961896896363 || test acc : 0.9966182112693787 ||  ExactMatch test Acc :0.9685
# 100%|██████████| 2250/2250 [01:41<00:00, 22.20it/s]
# 100%|██████████| 250/250 [00:04<00:00, 60.19it/s]
# 100%|██████████| 625/625 [00:09<00:00, 66.55it/s]
#   5%|▌         | 5/100 [09:31<3:01:23, 114.56s/it]
# epoch 4 || train loss : 1.2902296189202203 ||train acc : 0.9947373867034912 || ExactMatch train Acc :0.9479166666666666 || val loss : 1.2898617830276489 || val acc : 0.9965000152587891 ||  ExactMatch val Acc :0.968 ||test loss : 1.2886049385070801 || test acc : 0.9965817928314209 ||  ExactMatch test Acc :0.9682
# 100%|██████████| 2250/2250 [01:41<00:00, 22.16it/s]
# 100%|██████████| 250/250 [00:04<00:00, 61.03it/s]
# 100%|██████████| 625/625 [00:12<00:00, 48.95it/s]
#   6%|▌         | 6/100 [11:30<3:01:32, 115.88s/it]
# epoch 5 || train loss : 1.2901486699846056 ||train acc : 0.9947752356529236 || ExactMatch train Acc :0.9480833333333333 || val loss : 1.2898428974151612 || val acc : 0.9965000152587891 ||  ExactMatch val Acc :0.968 ||test loss : 1.2885864786148071 || test acc : 0.9965454339981079 ||  ExactMatch test Acc :0.9677
# 100%|██████████| 2250/2250 [01:59<00:00, 18.84it/s]
# 100%|██████████| 250/250 [00:04<00:00, 50.86it/s]
# 100%|██████████| 625/625 [00:12<00:00, 50.70it/s]
#   7%|▋         | 7/100 [13:46<3:10:09, 122.68s/it]
# epoch 6 || train loss : 1.2898538046942818 ||train acc : 0.9951995015144348 || ExactMatch train Acc :0.9518888888888889 || val loss : 1.2898183193206787 || val acc : 0.9965454339981079 ||  ExactMatch val Acc :0.9685 ||test loss : 1.288581279182434 || test acc : 0.9965454339981079 ||  ExactMatch test Acc :0.9678
# 100%|██████████| 2250/2250 [01:59<00:00, 18.78it/s]
# 100%|██████████| 250/250 [00:05<00:00, 48.78it/s]
# 100%|██████████| 625/625 [00:12<00:00, 48.23it/s]
#   8%|▊         | 8/100 [16:04<3:15:32, 127.53s/it]
# epoch 7 || train loss : 1.2899288397894966 ||train acc : 0.9950429201126099 || ExactMatch train Acc :0.9509722222222222 || val loss : 1.2898626575469971 || val acc : 0.9964772462844849 ||  ExactMatch val Acc :0.968 ||test loss : 1.2885616296768188 || test acc : 0.9965817928314209 ||  ExactMatch test Acc :0.9682
# 100%|██████████| 2250/2250 [01:58<00:00, 18.91it/s]
# 100%|██████████| 250/250 [00:04<00:00, 51.27it/s]
# 100%|██████████| 625/625 [00:12<00:00, 50.97it/s]
#   9%|▉         | 9/100 [18:20<3:17:29, 130.21s/it]
# epoch 8 || train loss : 1.289647921456231 ||train acc : 0.9953812956809998 || ExactMatch train Acc :0.95375 || val loss : 1.2898513278961181 || val acc : 0.9965454339981079 ||  ExactMatch val Acc :0.9685 ||test loss : 1.2886362779617309 || test acc : 0.9965454339981079 ||  ExactMatch test Acc :0.9677
# 100%|██████████| 2250/2250 [01:59<00:00, 18.90it/s]
# 100%|██████████| 250/250 [00:05<00:00, 49.42it/s]
# 100%|██████████| 625/625 [00:12<00:00, 51.87it/s]
#  10%|█         | 10/100 [20:36<3:18:04, 132.05s/it]
# epoch 9 || train loss : 1.2899487833446928 ||train acc : 0.9950504899024963 || ExactMatch train Acc :0.951 || val loss : 1.2898915457725524 || val acc : 0.9964772462844849 ||  ExactMatch val Acc :0.96825 ||test loss : 1.2886474153518677 || test acc : 0.9964818358421326 ||  ExactMatch test Acc :0.9679
# 100%|██████████| 2250/2250 [02:00<00:00, 18.67it/s]
# 100%|██████████| 250/250 [00:05<00:00, 49.29it/s]
# 100%|██████████| 625/625 [00:12<00:00, 50.07it/s]
#  11%|█         | 11/100 [22:54<3:18:36, 133.89s/it]
# epoch 10 || train loss : 1.2896793936623467 ||train acc : 0.9953712224960327 || ExactMatch train Acc :0.9537777777777777 || val loss : 1.289861198425293 || val acc : 0.9965227246284485 ||  ExactMatch val Acc :0.96825 ||test loss : 1.28862784614563 || test acc : 0.9965545535087585 ||  ExactMatch test Acc :0.968
# 100%|██████████| 2250/2250 [01:57<00:00, 19.21it/s]
# 100%|██████████| 250/250 [00:05<00:00, 45.32it/s]
# 100%|██████████| 625/625 [00:12<00:00, 49.80it/s]
#  12%|█▏        | 12/100 [25:10<3:16:57, 134.29s/it]
# epoch 11 || train loss : 1.2898578886985779 ||train acc : 0.9951288104057312 || ExactMatch train Acc :0.9516666666666667 || val loss : 1.2899676508903504 || val acc : 0.9963409304618835 ||  ExactMatch val Acc :0.96675 ||test loss : 1.288691650390625 || test acc : 0.9964545369148254 ||  ExactMatch test Acc :0.9673
# 100%|██████████| 2250/2250 [02:01<00:00, 18.57it/s]
# 100%|██████████| 250/250 [00:05<00:00, 48.12it/s]
# 100%|██████████| 625/625 [00:12<00:00, 50.48it/s]
#  13%|█▎        | 13/100 [27:28<3:16:41, 135.65s/it]
# epoch 12 || train loss : 1.2897043511072794 ||train acc : 0.9953863620758057 || ExactMatch train Acc :0.9538611111111112 || val loss : 1.289886923313141 || val acc : 0.9964772462844849 ||  ExactMatch val Acc :0.9675 ||test loss : 1.2886233057022094 || test acc : 0.9965454339981079 ||  ExactMatch test Acc :0.9676
#  56%|█████▋    | 1271/2250 [01:01<00:47, 20.66it/s]
#  13%|█▎        | 13/100 [28:30<3:10:47, 131.58s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /data1/home/armangupta/Semester 3/DLNLP/Assignment_4_A/Assignment4_character copy.ipynb Cell 31 in <cell line: 6>()
#       <a href='vscode-notebook-cell://ssh-remote%2B10.192.30.13/data1/home/armangupta/Semester%203/DLNLP/Assignment_4_A/Assignment4_character%20copy.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> encoder = encoder.to(device)
#       <a href='vscode-notebook-cell://ssh-remote%2B10.192.30.13/data1/home/armangupta/Semester%203/DLNLP/Assignment_4_A/Assignment4_character%20copy.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> decoder = decoder.to(device)
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.192.30.13/data1/home/armangupta/Semester%203/DLNLP/Assignment_4_A/Assignment4_character%20copy.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> train(encoder, decoder , trainloader , valloader,testloader, optimizer ,criteria , 100 , device)
#
# /data1/home/armangupta/Semester 3/DLNLP/Assignment_4_A/Assignment4_character copy.ipynb Cell 31 in train(encoder, decoder, trainloader, valloader, testloader, optimizer, criteria, epochs, device)
#      <a href='vscode-notebook-cell://ssh-remote%2B10.192.30.13/data1/home/armangupta/Semester%203/DLNLP/Assignment_4_A/Assignment4_character%20copy.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> # print(decoder_o ,onehotlabels)
#      <a href='vscode-notebook-cell://ssh-remote%2B10.192.30.13/data1/home/armangupta/Semester%203/DLNLP/Assignment_4_A/Assignment4_character%20copy.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> loss = criteria(decoder_o,onehotlabels)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B10.192.30.13/data1/home/armangupta/Semester%203/DLNLP/Assignment_4_A/Assignment4_character%20copy.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> loss.backward()
#      <a href='vscode-notebook-cell://ssh-remote%2B10.192.30.13/data1/home/armangupta/Semester%203/DLNLP/Assignment_4_A/Assignment4_character%20copy.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> # torch.nn.utils.clip_grad_norm_(encoder.parameters(), 5)
#      <a href='vscode-notebook-cell://ssh-remote%2B10.192.30.13/data1/home/armangupta/Semester%203/DLNLP/Assignment_4_A/Assignment4_character%20copy.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> # torch.nn.utils.clip_grad_norm_(decoder.parameters(), 5)
#      <a href='vscode-notebook-cell://ssh-remote%2B10.192.30.13/data1/home/armangupta/Semester%203/DLNLP/Assignment_4_A/Assignment4_character%20copy.ipynb#X42sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a> optimizer.step()
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/anaconda3/lib/python3.9/site-packages/torch/autograd/__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
